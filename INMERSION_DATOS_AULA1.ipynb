# %% [markdown]
# # CLASE 1 INMERSION DE DATOS

# %% [markdown]
# **Conectando Colab con Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Importando Documento desde Drive**

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
# **<h2>*Inmuebles.shape* </h2>**<br>
# Nos muestra la cantidad total de filas y columnas que tiene nuestra tabla de datos.

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %% [markdown]
# **inmuebles.columns** <br> Nos muestra el nombre de todas las columnas existentes.

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# # Renombrando Columnas

# %% [markdown]
# Para evitar que algunos caracteres de nuestra tabla generen en el futuro errores procedemos a renombralos y se renombraran creando un diccionario en pyton que despues se utlilizara para realizar el reemplazo.

# %%
columnas = {'Baños':'Banos', 'Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7006  Apartamento            Apartamento en venta en Cedritos             1
# 2811  Apartamento     Apartamento en venta en Chico Reservado             3
# 1151  Apartamento         Apartamento en venta en Teusaquillo             3
# 1267  Apartamento            Apartamento en venta en El Chicó             1
# 4511  Apartamento    Apartamento en venta en Colina Campestre             3
# 2485  Apartamento      Apartamento en venta en Chico Norte Ii             2
# 2572         Casa                       Casa en venta en Niza             2
# 8279  Apartamento                Apartamento en venta en Suba             2
# 8257  Apartamento            Apartamento en venta en Verbenal             2
# 3857  Apartamento  Apartamento en venta en Zona Noroccidental             3
#
#       Banos  Area              Barrio                                 UPZ  \
# ...

# %% [markdown]
# En la siguiente linea de codigo creamos el diccionario de reemplazo<br>
# **columnas = {'Baños':'Banos', 'Área':'Area'}**<br>
# En la siguiente linea de codigo le decimos a nuestro programa que a inmuebles se le va a renombrar las columnas mandando llamar a nuestro diccionario<br>
# **inmuebles = inmuebles.rename(columns=columnas)**<br>
# Finalmente mandamos pedir que nos muestre 10 datos de la tabla mediante la propiedad **sample** y esta lo ara de forma aleatoria.<br>
# **inmuebles.sample(10)**

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# Mediante el comando
# **inmuebles.info()**
# pedimos que nos muestre la informacion de nuestro documento
# Nos indica que es un Dataframe<br>
# Nos da el rango de indices que es de 0 a 9519<br>
# Nos da el total de columnas<br>
# Nos da el orden de las columas, sus nombres, la cantidad de columnas que no tienen valores nulos y el tipo de cada columna si es int objet etc.

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# **inmuebles.iloc**<br>
# Nos permite mandar llamar un indice especifico, hay que poner atencion en que el indice que nos mostro es el 301 ya que este toma encuenta desde el 0.

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %% [markdown]
# **inmuebles.iloc[300:305]**<br>
# Este comando nos permite mandar llamar indices en cierto rango determinado en este caso nos muestra del 300 al 304 por que el 300 no olvidemos que cuenta desde el 0.

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %% [markdown]
# **inmuebles['Valor'][300]**<br>
# En este caso nos permite mandar llamar de una forma mas especifica un atributo donde de forma inicial le indicamo que queremos ver el atributo Valor del indice 300.

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %% [markdown]
# **inmuebles['Valor'][300:305]**<br>
# Esta es otra forma mas especifica de mandar llamar atributos, en esta ocasion mandamos pedir el mismo atributo solo que ahora lo mezclamos con la solicitud de rango anterior.

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# **inmuebles.Area.mean()**<br>
# Nos muestra el Area promedio de tooodo el conjunto de datos que hay en inmuebles.

# %%
inmuebles.sample(100)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 5486         Casa               Casa en venta en Usaquén             3      3
# 4824  Apartamento        Apartamento en venta en Usaquén             2      1
# 1123         Casa            Casa en venta en Las Villas             4      3
# 1487  Apartamento        Apartamento en venta en Tintala             3      1
# 8248  Apartamento       Apartamento en venta en Engativa             3      2
# ...           ...                                    ...           ...    ...
# 1271         Casa              Casa en venta en Engativa             3      1
# 837   Apartamento       Apartamento en venta en Engativa             3      2
# 4281  Apartamento        Apartamento en venta en Usaquén             2      2
# 7328  Apartamento  Apartamento en venta en Puente Aranda             3      2
# 6832  Apartamento       Apartamento en venta en Cedritos             2      2
#
# ...

# %%
(inmuebles.Barrio == 'Santa Barbara')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# **(inmuebles.Barrio == 'Santa Barbara')**<br>
# Aqui mandamos llamar a todos los registros del atributo Barrio cuyo valor sea Santa Barbara.<br>
# Donde solo nos devuelve valores False o True
# los puntos intermedios son posibles True.

# %%
sum((inmuebles.Barrio == 'Santa Barbara'))
# Out:
# 438

# %% [markdown]
# **sum((inmuebles.Barrio == 'Santa Barbara'))**<br>
# Mediante el comando sum nos suma todos los valores del atruibuto Barrio con valor Santa Barbara y nos dice que son 438.

# %%
inmuebles_SBarbara = (inmuebles.Barrio == 'Santa Barbara')
type(inmuebles_SBarbara)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **inmuebles_SBarbara = (inmuebles.Barrio == 'Santa Barbara')**<br>
# Aqui colocamos una mascara con nombre inmuebles_SBarbara para igualar el comando de seleccion especifica.<br>
# **type(inmuebles_SBarbara)**<br>
# Nos mostrara el tipo de dato que es.

# %%
Santa_Barbara = inmuebles[inmuebles_SBarbara]
Santa_Barbara
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 46    Apartamento  Apartamento en venta en Santa Barbara             3      1
# 75    Apartamento  Apartamento en venta en Santa Barbara             3      1
# 99    Apartamento  Apartamento en venta en Santa Barbara             3      3
# 108   Apartamento  Apartamento en venta en Santa Barbara             1      2
# 117   Apartamento  Apartamento en venta en Santa Barbara             2      3
# ...           ...                                    ...           ...    ...
# 9350  Apartamento  Apartamento en venta en Santa Barbara             2      2
# 9356  Apartamento  Apartamento en venta en Santa Barbara             1      1
# 9397  Apartamento  Apartamento en venta en Santa Barbara             3      3
# 9419  Apartamento  Apartamento en venta en Santa Barbara             3      3
# 9441  Apartamento  Apartamento en venta en Santa Barbara             4      5
#
# ...

# %% [markdown]
# **Santa_Barbara = inmuebles[inmuebles_SBarbara]**<br>
# **Santa_Barbara**<br>
# Impriminos el resultado donde ahora si nos mostrara todos los valores correspondientes a Santa Barbara al final nos arrojara la cantidad de indices y columnas encontradas en relacion a la busqueda solicitada.

# %%
Santa_Barbara.Area.mean()
# Out:
# 124.86986301369863

# %% [markdown]
# **Santa_Barbara.Area.mean()**<br>
# Mediante el comando **Area** le pedimos que nos muestre el area en realcion al valor promedio Santa_Barbara.

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %% [markdown]
# **len(inmuebles.Barrio.value_counts)**<br>
# Solo nos muestra la cantidad de barrios que tengo sin nada en especifico solo la cantidad esto debido a la propipedad len().

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# **inmuebles.Barrio.value_counts()**<br>
# Sinembargo si yo retiro la propiedad len()<br>
# Este nos muestra todos los barrios ordenados de mayor a menor

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %% [markdown]
# **inmuebles.UPZ.value_counts()**<br>
# Ahora cambiamos la busqueda en  lugar de barrio ahora buscamos por UPZ..

# %%
inmuebles_Barrio = inmuebles.Barrio.value_counts()
inmuebles_Barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **inmuebles_Barrio = inmuebles.Barrio.value_counts()**<br>
# Mandamos llamar todo el contenido de inmuebles del atributo barrio
# **inmuebles_Barrio.plot.bar()**<br>
# Mediante el **"plot"** le decimos que nos muestre todo el contenido en una grafica.<br>
# Mediante el **"bar"** estamos especificamos el tipo de grafica en este caso de barras de ahi el "bar".<br>
# Nos mostro una gran cantidad de informacion dificl de leer ya que nos esta mostrando todo el contenido.

# %%
inmuebles_Barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **inmuebles_Barrio.head(10).plot.bar()**<br>
# Ahora para ser mas eficiente mediante el "head" le solicitamos los primeros diez.<br>
# El **head** sin el parametro manda las primeras 5

# %% [markdown]
# # Reto en Clase
# **Area Promedio de todos los inmuebles en los Barrios Top 10**

# %%
inmuebles_Area = inmuebles.groupby('Barrio')['Area'].count()
inmuebles_Area
# Out:
# Barrio
# Alameda                 1
# Alhambra               17
# Andes Norte             7
# Antonio Nariño         48
# Barrancas              15
#                      ...
# Villa Maria            13
# Villas De Granada      22
# Villemar               18
# Zona Franca             1
# Zona Noroccidental    877
# Name: Area, Length: 149, dtype: int64

# %% [markdown]
# Solicitamos un conteo de Barrio y Area.<br>
# **inmuebles_Area = inmuebles.groupby('Barrio')['Area'].count()**<br>
#
# El parametro **groupby** nos permite realizar operaciones grupal y combinar resultados en este caso combinamos Barrio y Area.<br>
# El parametro **count** nos realiza el conteo
#
# **inmuebles_Area**
# Mandamos a imprimir el resultado.

# %%
inmuebles_Area = inmuebles.groupby('Barrio')['Area'].median()
inmuebles_Area
# Out:
# Barrio
# Alameda               97.00
# Alhambra             164.00
# Andes Norte          108.00
# Antonio Nariño        72.00
# Barrancas             75.00
#                       ...
# Villa Maria          222.00
# Villas De Granada     64.00
# Villemar              59.00
# Zona Franca           54.00
# Zona Noroccidental    78.00
# Name: Area, Length: 149, dtype: float64

# %% [markdown]
# **inmuebles_Area = inmuebles.groupby('Barrio')['Area'].median()**<br>
# El comando **median** nos permite sacar la mediana sobre el eje solicitado.

# %%
inmuebles_Area = inmuebles.groupby('Barrio')['Area'].min()
inmuebles_Area
# Out:
# Barrio
# Alameda               97
# Alhambra              50
# Andes Norte           42
# Antonio Nariño        32
# Barrancas             63
#                       ..
# Villa Maria           51
# Villas De Granada     50
# Villemar              45
# Zona Franca           54
# Zona Noroccidental    16
# Name: Area, Length: 149, dtype: int64

# %% [markdown]
# **inmuebles_Area = inmuebles.groupby('Barrio')['Area'].min()**<br>
# El comando **min** nos devuelve el valor minimo sobre el eje solicitado.

# %%
inmuebles_Area = inmuebles.groupby('Barrio')['Area'].max()
inmuebles_Area
# Out:
# Barrio
# Alameda                 97
# Alhambra               360
# Andes Norte            180
# Antonio Nariño         554
# Barrancas               78
#                       ...
# Villa Maria            222
# Villas De Granada      260
# Villemar               224
# Zona Franca             54
# Zona Noroccidental    5458
# Name: Area, Length: 149, dtype: int64

# %% [markdown]
# **inmuebles_Area = inmuebles.groupby('Barrio')['Area'].max()**<br>
# El comando **max** nos devuelve el valor maximo sobre el eje solicitado.

# %%
inmueblesA = inmuebles_Area.head(10).sort_values(ascending=False)
inmueblesA.plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# **inmueblesA = inmuebles_Area.head(10).sort_values(ascending=False)**<br>
# Mediante **sort_values(ascending=False)** le estamos indicanod que nos ordene de mayor a menor, en caso de que no se lo indicaramos y solo colocaramos el **sort_values** el orden seria de menor a mayor<br>
# **inmueblesA.plot.bar()**<br>
# Mandamos imprimir los resultados en una grafica de barras como vimos anterior mente solo que ahora combinando Barrio y Area

# %% [markdown]
# # **CLASE 2 INMERSION DE DATOS**

# %% [markdown]
# <h2>Tratamiento de Datos y Primeros Graficos

# %%
inmuebles.info
# Out:
# <bound method DataFrame.info of              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# ...

# %% [markdown]
# **inmuebles.info**<br>
# Pedimos que nos muestre la infromacion de inmuebles

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# **type(inmuebles.Valor[0])**<br>
# Vemos el tipo de dato al que pertenece Valor

# %%
inmuebles.Valor[0] + inmuebles.Valor[1] + inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %% [markdown]
# **inmuebles.Valor[0] + inmuebles.Valor[1] + inmuebles.Valor[:5]**<br>
# Se muestra lo qu hay en Valor en el indice 0 mas lo que hay en el indice  mas lo que hay hasta el indice 5.<br>
# Notece que no hay espacio entre nuetros resultados<br>
# Al ser un string como nos mostro anteriormente aunque veamos nuemros no los suma solo los concatena por ser texto.

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %% [markdown]
# **inmuebles.Valor[0].split()**<br>
# Agregando la funcion split agregamos espacio entre el valor arrojado esto debido a que nuestro parametro split lo que hace es tomar el espacio en blanco ya que no le definimos nada y devolver una separacion.

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %% [markdown]
# **inmuebles.Valor.str.split(expand=True)**<br>
# Mediante el comando de expand =True convertimos nuestro panda series en formato dataframe por lo que es mas facil leer la informacion recabada osea nuestra informacion de Valor en dos columnas ya que fue spliteado "split".

# %%
Valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = Valor[0]
inmuebles['Precio'] = Valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8619  Apartamento  Apartamento en venta en Zona Noroccidental             1
# 394   Apartamento             Apartamento en venta en Tintala             3
# 7781  Apartamento           Apartamento en venta en Chapinero             3
#
#       Banos  Area              Barrio                                 UPZ  \
# 8619      1    56  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 394       2    54             Tintala                             Tintala
# 7781      3   202           Chapinero  CHAPINERO: Pardo Rubio + Chapinero
#
#                 Valor Moneda         Precio
# 8619    $ 324.000.000      $    324.000.000
# 394     $ 162.000.000      $    162.000.000
# 7781  $ 1.600.000.000      $  1.600.000.000

# %% [markdown]
# **Valor = inmuebles.Valor.str.split(expand=True)**<br>
# **inmuebles['Moneda'] = Valor[0]**<br>
# **inmuebles['Precio'] = Valor[1]**<br>
# Creamos dos nuevos atributos para nuestro DataFrame uno de nombre "Moneda" y otro de nombre "Precio" Moneda hubicado en 0 y precio hubicado en 1
# **inmuebles.sample(3)**<br>
# tomamos (3) ejemplos aleatorios (sample) y nos muestra la tabla con los dos nuevos campos donde moneda es nuestro signo de pesos y precio es el precio

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Vemos como nuestro valores siguen siendo estrings caracteres.<br>
# Aun no lo convertimos en numericos y para eso necesitamos realizar ciertos reglamentos.<br>
# Acontinuacion se realiza una sumatoria donde le resultado realmente no es una suma si no una concatenacion esto debido a que sigue siendo una cadena de carateres.

# %%
inmuebles['Precio'].sum()
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.0
# ...

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex=True)

# %% [markdown]
# **inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex=True)**<br>
# Mediante el parametro **replace** le indicamos que reemplace los valores que se indican, en este caso el primer valor en comillas simples**('.')** es el que sera reemplazado y el segundo es por el que sera reemplazado **('')**, como lo que queremos es borrar el punto se deja en blanco.

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %% [markdown]
# **inmuebles[['Precio','Barrio']]**<br>
# Mandamos llamar nuestra tabla con los atributos Precio y Barrio y podemos observar como el punto ya ha sido borrado, pero no debemos olvidar que aun sigue siendo una cadena de caracteres por lo que el sigueinte paso sera convertirlo a un tipo float ya que eso es lo mas conveniente.

# %%
inmuebles['Precio_millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %% [markdown]
# **inmuebles['Precio_millon'] = inmuebles.Precio.astype('float')/1000000**<br>
# tomamos nuestro data frame inmuebles y creamos una nueva variable columna que se llama precio _millon.<br>
# Mediante la funcion **astype** cambiaremos el tipo de dato a nuestro valores de inicio le decimo que que sera de tipo flotante y despues dibvidimos sobre un millon para reducir la cantidad de ceros que se estara manejando.
# **inmuebles.info()**<br>
# pedimos que nos muestre la informacion

# %% [markdown]
# # **Reto Anterior Clase 01**

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# **inmuebles.describe()**<br>
# La funcio **describe** nos devuelbe un dataframe (tbla de datos) con la siguiente informacion<br>
# **count**  arroja el conteo de filas que tenemos<br>
# **mean** Mediana o promedio<br>
# **std** Desvio Estandar<br>
# **min** Valor minimo<br>
# **%25** Primer cuartil<br>
# **%50** Segundo cuartil<br>
# **%75** Tercer cuartil<br>
# **max** Valor maximo<br>

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# **pd.set_option('display.precision', 2)
# la funcion **pd.set_option** nos mandamos llamar el paquete de opciones de panda y en este caso elegimos **display.precision,2** esto hace referencia al echo de que estamos manejando valores de tipo flotante y display.precision le marcamos la cantidad de digitos a imprimir despues del punto en este caso le marcamos que fueran **2**.<br>
# **pd.set_option('display.float_format', lambda x: '%.2f' % x)**<br>
# Display.float_format es un formato que nos perimte manejar la funcion lamba.<br>
# lambda x: '%.2f' % x
# lamda de x : espcificamos el formato de 2.float  signo de porsentaje y la variable a la que se le aplicara
# **inmuebles.describe()**

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %% [markdown]
# **inmuebles.loc[inmuebles.Habitaciones == 110]**<br>
# Realizamos una consulta especifica mediante el parametro **loc** localizamos los datos que queremos, indicando que nos localice en nuestro

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_millon
# 8401         180.00

# %%
inmuebles['Precio_millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **inmuebles['Precio_millon'].plot.hist(bins=100)**<br>
# **plot** nos hace el llamado a una grafica<br>
# **hist** indica histograma esto para ver la frecuencia de una variable, no hay que confundir con la grafica de barras.<br>
# **(bins=100)** nos indica el rango que vamos a manejar(es la separacion que habra en nuestros datos) en este caso le indicamos que sera de 100.<br>
# Mientras mas bins mas separaciones de barra se generan mientras menos bins la barra mas se concentra y menos util nos seria.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_millon', kde=True, hue ='Tipo')
grafica.set_title('Distribucion de Valores de los Inmuebles en Bogota')
plt.xlim((50,1000))
plt.ylim((0,20))
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Grafica_valores_inmuebles.png', format ='png')
plt.show()

# %% [markdown]
# **import matplotlib.pyplot as plt**<br>
# Importamos la biblioteca matplotlib con el paquete pyplot
# que es especifica para la generacion de graficos mas detallados
# **import seaborn as sns**<br>
# importamos la bibloteca seaborn las graficas de seaborn son mas sensillas que las de matplotlib
#
# **plt.figure(figsize=(10,6))**<br>
# aqui preparamos un lienzo de trabajo **figsize** nos permite seleccionar el parametro a manejar en este caso elegimos (10, 6) ancho y largo
# **grafica = sns.histplot(data=inmuebles, x='Precio_millon', kde=True, hue ='Tipo')**<br>
# **grafica = sns.histplot** ahora creamos el grafico de nuestro histograma<br>
# **(data=inmuebles, x='Precio_millo',)** ya con estos valores ya podemos graficar ya que es lo requerido para la generacion de histograma<br>
# **kde=True** kernel densidi(curva de densidad) nos ayuda mostrando una curva en relacion de los datos.<br>
# **hue='Tipo'** crea otra grafica sobreponiendo por encima visualizando las dos graficas a la vez.<br>
# **grafica.set_title('Distribucion de Valores de los Inmuebles en Bogota')**<br>
# Mediante **set_title** podemos colocar un titulo a nuestra grafica
# **plt.xlim((50,1000))**<br>
# xlim nos ayuda a poner limite sobre eje x asi que colocamos el limite de 50 a 100.<br>
# **plt.ylim((0,20))**<br>
# ylim de igual forma ayuda a colocar un limite pero ahora sobre eje de Y, lo limitamos de 0 a 20.<br>
# **plt.savefig('/content/drive/MyDrive/Colab Notebooks/Grafica_valores_inmuebles.png', format ='png')**<br>
# aqui mandamos guardar una imagen de nuestra grafica debemos especificar la ruta y al final colocar el nombre que deseemos con su extencion a guardar seguido del formato de la extencion
# **plt.show()**<br>
# show nos puestra la grafica

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_millon', kde=True, hue ='Tipo')
grafica.set_title('Distribucion de Valores de los Inmuebles en Bogota')
plt.xlim((50,1000))
plt.show()

# %% [markdown]
# # **Desafio en Aula CLASE 02**
# Estudiar mejor el histograma darle una pulida visual
# manejar 3 valores de inmuebles
# titulos metas conclusiones comparando precios entre precios de casas y fincas o casas vs apartamentos etc ejemplo
# precio del metro cuadrado por barrio y hacer el grafico mas adecuado para este nuevo valor
# precio por metro cuadrado hay que divivdir el precio entre los metros

# %%
inmuebles['Valor_m2_Millones'] = inmuebles['Precio_millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_millon  Valor_m2_Millones
# 0    $ 360.000.000      $   360000000         360.00               5.14
# 1    $ 670.000.000      $   670000000         670.00               3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00               7.78

# %% [markdown]
# sacamos el area por metro cuadrado, recordemos que el precio al ser string al convertirlo a bolean se tuvo que crear una nueva variable llamada precio_millon<br>
# **inmuebles['Valor_m2_Millones'] = inmuebles['Precio_millon']/inmuebles['Area']**<br>
# Para sacar el precio por m2 hay que dividir el precio total entre el area
# Dicho esto y recordando lo anterior procedemos a crear una nueva variable **Valor_m2_Millones** donde alojaremos el resultado y dividimos **Precio_millon** entre **Area**<br>
# **inmuebles.head(3)**<br>
# Mandamos imprimir solo 3 resultados para comprobar que se realizo esta accion.

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_millon  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00
# Alhambra                    3.00   2.94 190.41         752.35
# Andes Norte                 3.00   2.86 124.86         709.57
# Antonio Nariño              4.31   2.50 163.06         459.22
# Barrancas                   2.87   2.13  70.20         314.13
# ...                          ...    ...    ...            ...
# Villa Maria                 4.69   3.69 207.15         402.85
# Villas De Granada           3.45   2.32  86.59         282.30
# Villemar                    2.94   2.06  76.89         303.83
# Zona Franca                 2.00   1.00  54.00         160.00
# Zona Noroccidental          3.17   2.51 135.79         620.81
#
#                     Valor_m2_Millones
# Barrio
# Alameda                          5.98
# Alhambra                         4.33
# Andes Norte                      6.05
# Antonio Nariño                   3.53
# ...

# %% [markdown]
# **inmuebles.groupby('Barrio').mean()**<br>
# Vemos El promedio **(mean)** para cada uno de los barrios, solo que es informacion errada ya que lo saca en base a la sumatora de todos los barrios sin distinguir uno de otro cuando lo correcto seria realizar la sumatoria de todos los inmuebles de de cada grupo de barrios de forma separada y de ahi sacar el promedio. ejemplo sumar todos los alamenda y sacar promedio de alameda, todos los alhambra y sacar el promedio de alhambra.

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millones
# Barrio
# Alameda                          5.98
# Alhambra                        73.56
# Andes Norte                     42.35
# ...

# %% [markdown]
# **datos_barrio = inmuebles.groupby('Barrio').sum()**<br>
# Realizamos una sumatoria con la propíedad **sum** de cada uno de los atributos de cada grupos y se guarda en **datos_barrio**<br>
# **datos_barrio**<br>
# imprimimos y nos muestr la sumatoria realizada

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millones  Valor_m2_Barrio
# Barrio
# Alameda                          5.98             5.98
# Alhambra                        73.56             3.95
# ...

# %% [markdown]
# **datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_millon']/datos_barrio['Area']**<br>
# **datos_barrio['Valor_m2_Barrio']** creamos un nuevo atributo llamado *Valor_m2_Barrio* en nuestro dataframe *datos_barrio*<br>
# **= datos_barrio['Precio_millon'] / datos_barrio**
# Indicamos que nuestro atributo **Vlor_m2_Barrio** va a ser igual a dividir<br>
# el atributo **Precio_millon** de nuestro dataframe datos_barrio entre el atributo **Area** de nuestro dataframe datos_barrio, Cabe recalcar que aqui ya estan sumados por grupos los diferentes barrios y no estan sumados todos por igual como la rpiemra vez por lo que ahora nuestros datos de promedio media etc seran los correctos para cada barrio.**<br>
#
# **datos_barrio**<br>
# Imprimimos el resultado, notese que ya aparece nuestro nuevo atributo Valor_m2_Barrio y todos los atributos ahora nos muestra el valor por metro cuadrado de forma correcta ya que solo se tomo el precio y el area a sus correspondientes atributos y no a todos juntos como se hacia anteriormente

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %% [markdown]
# **m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])**<br>
# Creamos la variable m2_barrios la cual se le asignara muestro diccionario
# la propiedad **dict** nos sirve para crear un diccionario, en este caso tomamos los datos_barrio la columna Valor_m2_Barrio

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_millon  Valor_m2_Millones  \
# ...

# %% [markdown]
# **inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']**<br>
# voy a tomar mi columna inmbueles Valor_m2_Barrio y asignarle Barrio
# **inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)**<br>
# tomamos nuestra columna luego de ser asignada y le aremos un mapeamos mediante **map** el atributo m2_barrio el cual creamos anteriormente y contiene las areas de forma ya ordenada
# **inmuebles.head(5)**<br>
# mandamos imprimir 5 y observamos como el valor_m2_Barrio ya tiene el valor de nuestro ultimo resultado obtenido.

# %%
inmuebles['Barrio'].value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# <h2>ANALISANDO CUAL ES LA MEJOR GRAFICA QUE NOS PUDIERA SERVIR

# %% [markdown]
# **inmuebles['Barrio'].value_counts()**<br>
# Consultamos mediante un conteo

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %% [markdown]
# **top_barrios = inmuebles['Barrio'].value_counts()[:10].index**<br>
# Ahora consultamos de una manera mas especifica tomamos los 10 barrios con mas inmuebles el inice es el nombre del barrio, todo eso lo Almacenamos en una variable **top_barrios**, al ejecutar solo nos manda los indices osea los nombres mde los barrios.

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millones  Valor_m2_Barrio
# 0                 5.98             5.98
# 1                73.56             3.95
# ...

# %% [markdown]
# **datos_barrio.reset_index(inplace=True)**<br>
# Mediante el comando **reset** borramos la propiedad del index de nuestro dataframe datos_barrio al atributo Barrio.<br>
# Mediante el parametro **inplace** reemplazamos el index barrio y lo convertimos a una columna mas .<br>
# **datos_barrio**<br>

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millones  Valor_m2_Barrio
# 5              2070.61             2.96
# 10             1654.36             2.68
# 22             2853.23             5.03
# 24             2466.03             4.58
# ...

# %% [markdown]
# **datos_barrio.query('Barrio in @top_barrios')**<br>
# Realizamos una consulta a este dataset tomamos datos_barrios, el arroba se usa para hacer referencia a la variable a la cual nos estamos refiriendo eneste caso top_barrios ya que este contiene los indices.

# %% [markdown]
# <h2>APARTIR DE AQUI COMENZAMOS CON LA BUSQUEDA DE EL GRAFICO MAS ADECUADO PARA LOS DATOS ENCONTRADOS

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x= "Barrio", y = "Valor_m2_Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis= 'x', rotation = 45)

# %% [markdown]
# **plt.figure(figsize=(10,8))**<br>
# utilizamos la librerioa matplotlib y seaborn, creamos nuestro lienzo de 10,8
# **ax = sns.barplot(x= "Barrio", y = "Valor_m2_Barrio", data = datos_barrio.query('Barrio in @top_barrios'))**<br>
# Atribuimos a una variable **ax**, **sns.barplot** mandamos llamar la funcion de grafico de barras, **(x="Barrio", y="Valor_m2_Barrio")** en nuestro eje de x tendremos a Barrio y en nuestro eje de y tendremos a Valor_m2_Barrio, **data = datos_barrio.query('Barrio in @top_barrios')** data mandamos llamar nuestro conjunto de datos, hacemos usos del conjunto de datos de nuestra consulta top 10 para graficar ese top 10 que habiamos realizado anteriormente
# **ax.tick_params(axis= 'x', rotation = 45)**<br>
# **ax** donde almacenamos nuestro grafico, **tick_params** son los indicadores ineriores **(axis = 'x', rotation = 45)** generanod una inclinacion de 45 grados para qeus e aprecien mejor nuestras etiquetas

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x= "Barrio", y = "Valor_m2_Millones", data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis= 'x', rotation = 45)
plt.show()

# %% [markdown]
# **plt.figure(figsize=(10,8))**<br>
# **ax = sns.boxplot(x= "Barrio", y = "Valor_m2_Millones", data = inmuebles.query('Barrio in @top_barrios'))**<br>
# Ahora cambiamos a el metodo **sns.boxplot** (boxplot= Grafico de Cajas) el cual nos ayudara a graficar de forma estadistica, cambiamos los valores que queremos ver y ahora colocamos **Valor_m2_Millones**
# **ax.tick_params(axis= 'x', rotation = 45)**<br>
# **plt.show()**
# esta calusula muestra nuestro grafico como tal.

# %% [markdown]
# <h2>CMOMO LEER ESTA GRAFICA
# El valor minimo y maximo se muestra a cada uno de los extremos de los segmentos, la parte inferior de la primera caja hace referencia al primer cuartil esto significa que el %25 de nuestros datos estaran por de bajo de este valor, a la mitad se encuentra la mediana o segundo cuartil de igual forma apartir de este punto por debajo estaran nuestros datos del %50, luego viene el tercer cuartil o %75 es la linea superior de nuestra caja y de igual forma los valores por debajo de esta linea son los que se utilizaran, y por ultimo la linea superiorfinal que representa el %100 y todo por debajo es lo que lo representa nuestro boxplot no toma el valor mas alto ya que hay valores que considera fuera de lo normal y los excluye; tambien notamos ciertos valores que estan fuera de estos segmentos, esos valores son valores que el programa detecto como anormales o irreales valores que estan fuera de patron

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x= "Barrio", y = "Valor_m2_Millones", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millones < 15'))
ax.tick_params(axis= 'x', rotation = 45)
plt.show()

# %% [markdown]
# **plt.figure(figsize=(10,8))**<br>
# **ax = sns.boxplot(x= "Barrio", y = "Valor_m2_Millones", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millones < 15'))**<br>
# Generamos una condicion para eliminar los outlayer (valores fuera de rango normal) **& Valor_m2_Millones < 15** lo condicionamos a Valor_m2_Millones dbera estar menor a 15 millones.
# **ax.tick_params(axis= 'x', rotation = 45)**<br>
# **plt.show()**<br>

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x= "Barrio", y = "Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis= 'x', rotation = 45)
plt.show()

# %% [markdown]
# **plt.figure(figsize=(10,8))**<br>
# **ax = sns.boxplot(x= "Barrio", y = "Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))**<br>
# Ahora hacemos una prueba con Y = Area con nuestros datos inmuebles y cambiamos la condicion a Area menor a 500.
# **ax.tick_params(axis= 'x', rotation = 45)**<br>
# **plt.show()**<br>

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x= "Barrio", y = "Precio_millon", data = inmuebles.query('Barrio in @top_barrios & Precio_millon < 2000'))
ax.tick_params(axis= 'x', rotation = 45)
plt.show()

# %% [markdown]
# **plt.figure(figsize=(10,8))**<br>
# **ax = sns.boxplot(x= "Barrio", y = "Precio_millon", data = inmuebles.query('Barrio in @top_barrios'))**<br>
# Esta vez usamos el atributo Precio_millo y cambiamos nuevamente la condicional Precio_millo menor a 2000.<br>
# **ax.tick_params(axis= 'x', rotation = 45)**<br>
# **plt.show()**<br>

# %% [markdown]
# # **CLASE 03 PROFUNDIZANDO EL ANALISIS EXPLORATORIO**

# %% [markdown]
# # **CRUZANDO BASES Y MACHINE LEARNING**

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Identificación (Capítulo A).csv', sep = ';', encoding = 'latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Datos de la vivenda y su entorno (Capítulo B).csv', sep = ';', encoding = 'latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Educación (Capítulo H).csv', sep = ';', encoding = 'latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep = ';', encoding = 'latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Fuerza de trabajo (Capítulo K).csv', sep = ';', encoding = 'latin-1')
# Out:
# <ipython-input-167-5ae756bef605>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'latin-1')
# <ipython-input-167-5ae756bef605>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'latin-1')
# <ipython-input-167-5ae756bef605>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Educación (Capítulo H).csv', sep = ';', encoding = 'latin-1')
# ...

# %%
datos_dane = pd.merge(datos_raw, datos_b, on = 'DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %% [markdown]
# La funcion merge crea una funcion de tablas

# %%
datos_dane = pd.merge(datos_dane, datos_c, on = 'DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane, datos_e, on = 'DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-170-71b8fed4b7d5>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane, datos_e, on = 'DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.shape
# Out:
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# <h2>DESAFIO AULA 4
# 1.-Dar un vistaso a la base de datos DANE, entender estas variables conceptualmente para entender mejor el contexto de la base de esta datos.<br>
# 2.-Organizar tu Notebook para que tu proyecto quede mejor resentado.

# %% [markdown]
# # **AULA 4 CRUZANDO BASES DE DATOS Y MACHINE LEARNING**

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/datos_dane.csv')
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %% [markdown]
# **datos_dane =** creamos nuestra variable donde se alojara nuestros datos<br>
# Mediante el comando **pd.read_csv('/direccion/de/neustro/archivo/con_su_nombre_y.extencion')** mandamos llamar un archivo externo de tipo csv
# recordemos que el comando head nos manda llamar las primeras 5 filas de datos, y al final nos dice 5 filas y 55 columnas.

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %% [markdown]
# **.shape** nos sirve para saber el conteo general de filas y columnas

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %% [markdown]
# **.info()** no infica la informacion y observamos que el documento viene en codigo donde existe un archivo a parte donde nos indica a que corresponde cada codigo

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %% [markdown]
# dic_dane = {
#        'NVCBP4':'CONJUNTO_CERRADO',<br>
#          }
#
# datos_dane = datos_dane.rename(columns=dic_dane)
# Una vez hubicado a que corresponde cada codigo procedemos a reemplazar cada codigo, creamos un diccionario con nombre **dic_dane**, le decimos **'codigo' : 'renombre'** para cada uno de los codigos.<br>
# **datos_dane = datos_dane.rename(columns=dic_dane)**<br>
# como vimos anteriormente renombramos datos de la columna **column** y los reemplazamos por los datos del diccionario **dic_dane**

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %% [markdown]
# Vemos como nuestros datos de **column** fueron actualizados correctamente.

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %% [markdown]
# **by('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()**<br>
# Sacamos el promedio mediante el **mean**, recordemos que el head nos arroja 5 filas de datos

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %% [markdown]
# **datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)**<br>
# asignamos nuestros datos a una nueva variable llamada **datos al mismo timpo que reemplazamas los 2 por 0 de manera que nos quede un sistema binario de datos<br>
# **datos** y pedimos que nos muestre los resultados

# %%
datos.NOMBRE_ESTRATO.value_counts()
# Out:
# Niza                                                   243
# SUBA: La Academia + Guaymaral + San José de Bavaria    212
# CHAPINERO: Chicó Lago + El Refugio                     210
# Los Libertadores                                       208
# Modelia                                                205
#                                                       ...
# Tunjuelito                                              26
# Lourdes                                                 25
# Localidad Chapinero resto                               21
# Localidad Usaquén resto                                 10
# Localidad Santa Fe resto                                 8
# Name: NOMBRE_ESTRATO, Length: 102, dtype: int64

# %% [markdown]
# Hay que verificar que nuestros datos no se vean afectdos durante la sustitucion ya que se podria dar el caso y es mejor estar seguros

# %%
datos.loc[datos.NOMBRE_ESTRATO == '20 Julio']
# Out:
# Empty DataFrame
# Columns: [NOMBRE_ESTRATO, CONJUNTO_CERRADO, INSEGURIDAD, TERMINALES_BUS, BARES_DISCO, RUIDO, OSCURO_PELIGROSO, SALARIO_MES, TIENE_ESCRITURA, PERDIDA_TRABAJO_C19, PERDIDA_INGRESOS_C19, PLANES_ADQUIRIR_VIVIENDA]
# Index: []

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %% [markdown]
# **datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()**<br>
# Agrupamos los datos y los gruadamos en la variable **datos_tratados** y calulamos el promedio nuevamente imprimiendo los priero 5<br>
# **datos_tratados** mostramos los datos

# %%
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %% [markdown]
# **pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')**<pr>
# Aqui combinamos nuestras bases de datos **inmuebles** y **datos_tratados**, mediate el paramtero **pd.merge**, y mediante el parametro **left_on='UPZ'** indicamos que la tabla upz y sus datos estaran del lado izquiero y mediante **right_on='NOMBRE_ESTRATO'** indicamos que la tabla NOMBRE_ESTRATO y sus datos estaran del lado derecho.<br>
# De inicio notamos que nos aparecen muchos campos con **NaN** no hay datos esto se debe a que usamos el **head** donde solo pediamos los primeros datos y se corrige retirandolo simplemente para que termine de cargar todos los datos.

# %% [markdown]
# Como dato extra recordemos que podemos mandar llamar cualquier variable, jugar con el llamado de variables segun nos convenga.

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_millon             9520 non-null   float64
#  11  Valor_m2_Millones         9520 non-null   float64
#  12  Valor_m2_Barrio           9520 non-null   float64
# ...

# %% [markdown]
# **datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# datos_ml.info()**<br>
# Guardamos nuestro merge en una nueva variable **llamada datos_ml**

# %% [markdown]
# Como UPZ esta en tipo objeto y lo necesitamos en modo numerico, se cuenta con los datos ya tratados de upz en otro archivo el cual mandamos llamar

# %%
upz = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/cod_upz.csv')
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ', right_on='NOMBRE_ESTRATO', how = 'inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %% [markdown]
# **upz = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/cod_upz.csv')
# upz.head()**<br>
# mandamos llamar el archivo externo y mostramos los primeros 5 datos

# %% [markdown]
# **datos_ml = pd.merge(datos_ml,upz,left_on='UPZ', right_on='NOMBRE_ESTRATO', how = 'inner')**<br> Hacemos un merge entre datos_ml y upz y lo guerdamos en nuestra variable datos_ml, isaremos el parametro **how= 'inner'** para que al llamar a upz estas sean solo las que tengan correspondencia considerando que hay barrios que no estan dentro de las upz.
# **datos_ml.head** Y mandamos llamar los datos

# %%
datos_ml.shape
# Out:
# (9318, 26)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data = datos_ml, y ='Precio_millon')
plt.show()

# %%
datos_ml.query('Precio_millon > 1200 & Precio_millon < 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 2            Casa         Casa en venta en Zona Noroccidental             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4            Casa         Casa en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 2      48.42
# 3      48.42
# 4      48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 9318, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data = datos_ml, x = 'SALARIO_ANUAL_MI', y ='Valor_m2_Millones')
#plt.ylim(())
plt.show()

# %% [markdown]
# <h2>GRAFICA DE DISPERSION<BR>
# scatterplot

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = datos_ml, x = 'SALARIO_ANUAL_MI', y ='Valor_m2_Millones')
plt.ylim((0,15))
plt.show()

# %%
datos_ml.corr()
# Out:
#                           Habitaciones  Banos  Area  Precio_millon  \
# Habitaciones                      1.00   0.48  0.04           0.24
# Banos                             0.48   1.00  0.06           0.59
# Area                              0.04   0.06  1.00           0.06
# Precio_millon                     0.24   0.59  0.06           1.00
# Valor_m2_Millones                -0.21   0.10 -0.03           0.43
# Valor_m2_Barrio                  -0.17   0.17 -0.03           0.30
# CONJUNTO_CERRADO                 -0.11   0.16 -0.01           0.18
# INSEGURIDAD                       0.11  -0.20 -0.01          -0.23
# TERMINALES_BUS                    0.06  -0.16 -0.01          -0.16
# BARES_DISCO                       0.11  -0.08 -0.01          -0.07
# RUIDO                             0.12  -0.18 -0.01          -0.22
# OSCURO_PELIGROSO                  0.09  -0.20  0.01          -0.20
# SALARIO_MES                      -0.14   0.21 -0.00           0.29
# ...

# %% [markdown]
# **.corr** Nos ´permite visualizar la relacion que exite entre las tablas siendo 1 indicativo de que es una relacion directa y numeros negativos indicando una relacion indirecta y cero no existe ningun tipo de correlacion

# %% [markdown]
# <H2>HEATMAP<BR>
# Mapas de Calor

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# Importando la biblioteca scikit - learn **sklearn**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml[['Precio_millon']]

x_train, x_test,  y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 99)

# %%
x_train
# Out:
#       COD_UPZ_GRUPO
# 4683          47.00
# 445          816.00
# 2560          14.00
# 2465          14.00
# 7819          85.00
# ...             ...
# 5188         101.00
# 7890          85.00
# 1768         817.00
# 3240          14.00
# 7203          20.00
#
# [6988 rows x 1 columns]

# %%
x_test
# Out:
#       COD_UPZ_GRUPO
# 4375          47.00
# 6953          75.00
# 4611          47.00
# 7141          13.00
# 6555          74.00
# ...             ...
# 4553          47.00
# 3013          14.00
# 3558          14.00
# 5721          27.00
# 14           816.00
#
# [2330 rows x 1 columns]

# %%
y_train
# Out:
#       Precio_millon
# 4683         220.00
# 445         3000.00
# 2560         380.00
# 2465         812.96
# 7819         131.00
# ...             ...
# 5188         379.00
# 7890         130.00
# 1768         700.00
# 3240         465.00
# 7203        1400.00
#
# [6988 rows x 1 columns]

# %%
y_test
# Out:
#       Precio_millon
# 4375         150.00
# 6953         850.00
# 4611         140.00
# 7141         450.00
# 6555         215.00
# ...             ...
# 4553         172.00
# 3013        1600.00
# 3558         394.00
# 5721        1400.00
# 14          1800.00
#
# [2330 rows x 1 columns]

# %% [markdown]
# <h2>EN ESTE PUNTO SE CREA EL MACHINE LEARN

# %%
modelo = LinearRegression()

# %%
modelo.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict_test = modelo.predict(x_test)

# %% [markdown]
# <h2>Fue creado cargado y se procede a validar

# %%
from sklearn.metrics import mean_absolute_error, r2_score
baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
print(baseline_mae, baseline_r2)
# Out:
# 409.2101269549263 0.014629923194031336

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']] #,'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA'

Y = datos_ml["Precio_millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 285.26555541202674 0.3863951687002952
# 268.504664306373 0.38061056364162016

# %%
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[510.04001974]])
